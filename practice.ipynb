# %% [markdown]
# ## Practicing matplotilib functionalities

# %%
import matplotlib.pyplot as plt
import numpy as np
from mat import Plotting

# %%
plotter = Plotting()

# %% [markdown]
# Line Plotting

# %%
plotter.line_plot()

# %% [markdown]
# Scattered Plotting

# %%
plotter.scatter_plot()

# %% [markdown]
# Bar Graphs

# %%
plotter.bar_graphs()

# %% [markdown]
# Histograms

# %%
plotter.histograms()

# %% [markdown]
# Pie Charts

# %%
plotter.pie_charts()
